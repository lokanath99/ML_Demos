# %% [markdown]
# # Pandas Demo

# %%
import pandas as pd

data = {
    'Calories':[450,520,390],
    'Duration':[60,75,50]
}

df = pd.DataFrame(data, index=['a','b','c'])

# %%
df
# Out:
#    Calories  Duration
# a       450        60
# b       520        75
# c       390        50

# %%
df['Calories']
# Out:
# a    450
# b    520
# c    390
# Name: Calories, dtype: int64

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.loc['a']
# Out:
# Calories    450
# Duration     60
# Name: a, dtype: int64

# %%
df.iloc[1]
# Out:
# Calories    520
# Duration     75
# Name: b, dtype: int64

# %%
df = pd.read_csv("C:\\Users\lokanath\Downloads\data.csv")
df
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.tail()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   164.000000
# mean    63.846154  107.461538  134.047337   375.790244
# std     42.299949   14.510259   16.450434   266.379919
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   250.925000
# 50%     60.000000  105.000000  131.000000   318.600000
# 75%     60.000000  111.000000  141.000000   387.600000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
# df['Calories'].mode()
df['Calories'].fillna(df['Calories'].mode()[0], inplace=True)
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   169.000000
# mean    63.846154  107.461538  134.047337   373.547929
# std     42.299949   14.510259   16.450434   262.701937
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   253.300000
# 50%     60.000000  105.000000  131.000000   310.200000
# 75%     60.000000  111.000000  141.000000   384.000000
# max    300.000000  159.000000  184.000000  1860.400000

# %%
# new_df = df.dropna()
# new_df.describe()
df.dropna(inplace=True)
df.describe()
# Out:
#          Duration       Pulse   Maxpulse     Calories
# count  164.000000  164.000000  164.00000   164.000000
# mean    64.146341  107.676829  134.27439   375.790244
# std     42.888820   14.637516   16.58306   266.379919
# min     15.000000   80.000000  100.00000    50.300000
# 25%     45.000000  100.000000  124.00000   250.925000
# 50%     60.000000  105.500000  131.00000   318.600000
# 75%     60.000000  111.000000  143.00000   387.600000
# max    300.000000  159.000000  184.00000  1860.400000

# %%
for x in df.index:
    if df.loc[x, "Duration"] > 120:
        df.loc[x, "Duration"] = 120

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse     Calories
# count  169.000000  169.000000  169.000000   169.000000
# mean    58.579882  107.461538  134.047337   373.547929
# std     25.267518   14.510259   16.450434   262.701937
# min     15.000000   80.000000  100.000000    50.300000
# 25%     45.000000  100.000000  124.000000   253.300000
# 50%     60.000000  105.000000  131.000000   310.200000
# 75%     60.000000  111.000000  141.000000   384.000000
# max    120.000000  159.000000  184.000000  1860.400000

# %%
for x in df.index:
    if df.loc[x, "Calories"] > 600:
        df.loc[x, "Calories"] = 600

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count  169.000000  169.000000  169.000000  169.000000
# mean    58.579882  107.461538  134.047337  331.780473
# std     25.267518   14.510259   16.450434  129.334796
# min     15.000000   80.000000  100.000000   50.300000
# 25%     45.000000  100.000000  124.000000  253.300000
# 50%     60.000000  105.000000  131.000000  310.200000
# 75%     60.000000  111.000000  141.000000  384.000000
# max    120.000000  159.000000  184.000000  600.000000

# %%
df["Calories"].dtype
# Out:
# dtype('float64')

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
for e in df.duplicated():
    if e == True:
        print('yes')
        break
# Out:
# yes

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count  169.000000  169.000000  169.000000  169.000000
# mean    58.579882  107.461538  134.047337  331.780473
# std     25.267518   14.510259   16.450434  129.334796
# min     15.000000   80.000000  100.000000   50.300000
# 25%     45.000000  100.000000  124.000000  253.300000
# 50%     60.000000  105.000000  131.000000  310.200000
# 75%     60.000000  111.000000  141.000000  384.000000
# max    120.000000  159.000000  184.000000  600.000000

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#          Duration       Pulse    Maxpulse    Calories
# count  162.000000  162.000000  162.000000  162.000000
# mean    58.703704  107.709877  134.265432  333.391358
# std     25.765037   14.711588   16.471618  131.119372
# min     15.000000   80.000000  100.000000   50.300000
# 25%     45.000000  100.000000  124.000000  255.075000
# 50%     60.000000  105.500000  131.000000  317.850000
# 75%     60.000000  111.000000  141.000000  386.700000
# max    120.000000  159.000000  184.000000  600.000000

# %% [markdown]
# # Supervised Learning

# %% [markdown]
# ## Classification

# %%
import pandas as pd 
data = pd.read_csv('C:\\Users\lokanath\Downloads\spotify_data.csv')
data.head()
# Out:
#    danceability  energy  key  loudness  mode  ...  valence    tempo  duration_ms  time_signature  liked
# 0         0.803  0.6240    7    -6.764     0  ...   0.6280   95.968       304524               4      0
# 1         0.762  0.7030   10    -7.951     0  ...   0.5190  151.329       247178               4      1
# 2         0.261  0.0149    1   -27.528     1  ...   0.0382   75.296       286987               4      0
# 3         0.722  0.7360    3    -6.994     0  ...   0.5820   89.860       208920               4      1
# 4         0.787  0.5720    1    -7.516     1  ...   0.6470  155.117       179413               4      1
#
# [5 rows x 14 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   danceability      195 non-null    float64
#  1   energy            195 non-null    float64
#  2   key               195 non-null    int64
#  3   loudness          195 non-null    float64
#  4   mode              195 non-null    int64
#  5   speechiness       195 non-null    float64
#  6   acousticness      195 non-null    float64
#  7   instrumentalness  195 non-null    float64
#  8   liveness          195 non-null    float64
#  9   valence           195 non-null    float64
#  10  tempo             195 non-null    float64
#  11  duration_ms       195 non-null    int64
#  12  time_signature    195 non-null    int64
#  13  liked             195 non-null    int64
# dtypes: float64(9), int64(5)
# memory usage: 21.5 KB

# %%
data.isna().sum()
# Out:
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# duration_ms         0
# time_signature      0
# liked               0
# dtype: int64

# %%
data.describe()
# Out:
#        danceability      energy         key    loudness  ...       tempo    duration_ms  time_signature       liked
# count    195.000000  195.000000  195.000000  195.000000  ...  195.000000     195.000000      195.000000  195.000000
# mean       0.636656    0.638431    5.497436   -9.481631  ...  121.086174  213408.933333        3.912821    0.512821
# std        0.216614    0.260096    3.415209    6.525086  ...   28.084829   72152.392864        0.451332    0.501122
# min        0.130000    0.002400    0.000000  -42.261000  ...   60.171000   77203.000000        1.000000    0.000000
# 25%        0.462500    0.533500    2.000000   -9.962000  ...  100.242000  178300.500000        4.000000    0.000000
# 50%        0.705000    0.659000    6.000000   -7.766000  ...  124.896000  204000.000000        4.000000    1.000000
# 75%        0.799000    0.837500    8.000000   -5.829000  ...  142.460500  242373.500000        4.000000    1.000000
# ...

# %%
data.corr()
# Out:
#                   danceability    energy       key  loudness  ...     tempo  duration_ms  time_signature     liked
# danceability          1.000000  0.137188 -0.063906  0.455078  ...  0.223522    -0.232621        0.317096  0.569425
# energy                0.137188  1.000000  0.130251  0.813567  ...  0.214905    -0.134527        0.123942  0.176179
# key                  -0.063906  0.130251  1.000000  0.046865  ...  0.097240     0.054522        0.048344 -0.044406
# loudness              0.455078  0.813567  0.046865  1.000000  ...  0.274462    -0.206334        0.207806  0.410774
# mode                  0.043759 -0.068308 -0.103371 -0.041678  ... -0.036270    -0.060965       -0.110739  0.023747
# speechiness           0.388596  0.122825 -0.093395  0.279710  ...  0.313918    -0.388397        0.140325  0.591505
# acousticness         -0.234176 -0.772583 -0.066844 -0.664989  ... -0.255097     0.138793       -0.142177 -0.179375
# ...

# %%
# data.drop(columns=['key', 'mode', 'liveness'], inplace=True)

# %%
data.corr()
# Out:
#                   danceability    energy  loudness  speechiness  ...     tempo  duration_ms  time_signature     liked
# danceability          1.000000  0.137188  0.455078     0.388596  ...  0.223522    -0.232621        0.317096  0.569425
# energy                0.137188  1.000000  0.813567     0.122825  ...  0.214905    -0.134527        0.123942  0.176179
# loudness              0.455078  0.813567  1.000000     0.279710  ...  0.274462    -0.206334        0.207806  0.410774
# speechiness           0.388596  0.122825  0.279710     1.000000  ...  0.313918    -0.388397        0.140325  0.591505
# acousticness         -0.234176 -0.772583 -0.664989    -0.079710  ... -0.255097     0.138793       -0.142177 -0.179375
# instrumentalness     -0.807053 -0.241444 -0.538266    -0.343242  ... -0.299493     0.249683       -0.375199 -0.569440
# valence               0.612344  0.319409  0.363532     0.180708  ...  0.218017    -0.114842        0.201111  0.268653
# ...

# %%
data.columns
# Out:
# Index(['danceability', 'energy', 'loudness', 'speechiness', 'acousticness',
#        'instrumentalness', 'valence', 'tempo', 'duration_ms', 'time_signature',
#        'liked'],
#       dtype='object')

# %%
x = data.iloc[:,:-1]
y = data.iloc[:, -1]
# Out:
# 0      0
# 1      1
# 2      0
# 3      1
# 4      1
#       ..
# 190    0
# 191    0
# 192    0
# 193    1
# 194    1
# Name: liked, Length: 195, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train ,x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

from sklearn.ensemble import RandomForestClassifier

cls = RandomForestClassifier()
cls.fit(x_train, y_train)
#trained the model 

y_pred = cls.predict(x_test)
res = pd.DataFrame({
    "Actual": y_test,
    "predicted": y_pred
})

from sklearn import metrics as mt 
print(mt.accuracy_score(y_test, y_pred))
res.hist()
# Out:
# 0.8974358974358975
# array([[<AxesSubplot: title={'center': 'Actual'}>,
#         <AxesSubplot: title={'center': 'predicted'}>]], dtype=object)

# %%
from numpy import array
a = array(x.iloc[4]).reshape(1, -1)
print(pred, y.iloc[4])
b = array([[0.287,0.992,7.516,0.111,0.000,0.77,0.178,128,179400,4]])
pred = cls.predict(b)
print(pred)
# Out:
# [0] 1
# [0]
# C:\Users\lokanath\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
x.iloc[10] 
y.iloc[10]
# Out:
# 0

# %% [markdown]
# ## Regression

# %%
import pandas as pd 
data = pd.read_csv('C:\\Users\lokanath\Downloads\\advertising.csv')
data.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3   12.0
# 3  151.5   41.3       58.5   16.5
# 4  180.8   10.8       58.4   17.9

# %%
data.isna().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
data.duplicated().sum()
# Out:
# 0

# %%
x = data.iloc[:, :-1]
y = data.iloc[:, -1]

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=100)

from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor()
reg.fit(x_train, y_train)
y_pred = reg.predict(x_test)
from numpy import array

res = pd.DataFrame({"Predicted":y_pred, "actual": array(y_test).flatten()})

from sklearn import metrics as mt 
print(mt.r2_score(y_pred,  array(y_test).flatten()))
# Out:
# 0.933592681348029
